# %%
# -------------------- Import Libraries --------------------
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# -------------------- Load Dataset --------------------
df = pd.read_csv("insurance.csv")

# -------------------- Select Required Columns --------------------
df = df[["sex", "smoker", "region", "charges"]]

# -------------------- Encode Categorical Data --------------------
le = LabelEncoder()

df["sex"] = le.fit_transform(df["sex"])
df["smoker"] = le.fit_transform(df["smoker"])
df["region"] = le.fit_transform(df["region"])

# -------------------- Features & Target --------------------
x = df.drop("charges", axis=1)
y = df["charges"]

# -------------------- Train-Test Split --------------------
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
)

# ==================== Linear Regression ====================
lr_model = LinearRegression()
lr_model.fit(x_train, y_train)

y_pred_lr = lr_model.predict(x_test)

# Evaluation
lr_mae = mean_absolute_error(y_test, y_pred_lr)
lr_rmse = np.sqrt(mean_squared_error(y_test, y_pred_lr))
lr_r2 = r2_score(y_test, y_pred_lr)

print("\n=== Linear Regression ===")
print("MAE:", lr_mae)
print("RMSE:", lr_rmse)
print("R2 Score:", lr_r2)

# ==================== Decision Tree ====================
dt_model = DecisionTreeRegressor(random_state=42)
dt_model.fit(x_train, y_train)

y_pred_dt = dt_model.predict(x_test)

# Evaluation
dt_mae = mean_absolute_error(y_test, y_pred_dt)
dt_rmse = np.sqrt(mean_squared_error(y_test, y_pred_dt))
dt_r2 = r2_score(y_test, y_pred_dt)

print("\n=== Decision Tree ===")
print("MAE:", dt_mae)
print("RMSE:", dt_rmse)
print("R2 Score:", dt_r2)

# -------------------- Comparison --------------------
print("\n=== Model Comparison ===")
print("Linear Regression R2:", lr_r2)
print("Decision Tree R2:", dt_r2)

if lr_r2 > dt_r2:
    print("Linear Regression performs better")
elif dt_r2 > lr_r2:
    print("Decision Tree performs better")
else:
    print("Both models perform equally")
# Out:
# === Linear Regression ===
# MAE: 5636.684167341957
# RMSE: 7271.973798723797
# R2 Score: 0.6593749757489802
#
# === Decision Tree ===
# MAE: 5586.079895813562
# RMSE: 7382.268442192519
# R2 Score: 0.6489640409365962
#
# === Model Comparison ===
# Linear Regression R2: 0.6593749757489802
# Decision Tree R2: 0.6489640409365962
# Linear Regression performs better
